# %%
import numpy as np
import numpy.random as rnd
# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/magics/extension.py:47: UserWarning: %install_ext` is deprecated, please distribute your extension as a python package.
#   "as a python package.", UserWarning)
# Installed autotime.py. To use it, type:
#   %load_ext autotime

# %%
6**50
# Out:
# 808281277464764060643139600456536293376

# %%
print("%.4g" % 6**50)
# Out:
# 8.083e+38

# %%
6**8
# Out:
# 1679616

# %%
np.std([5,8,9,8,5])
# Out:
# 1.6733200530681511

# %%
(14/5)**.5
# Out:
# 1.6733200530681511

# %%
q = [2]

# %%
q += [3]

# %%
print(q)
# Out:
# [2, 3]

# %%
q.append(4)

# %%
print(q)
# Out:
# [2, 3, 4]

# %%
successful_rolls_init = 
current_roll_init = []

def enumerate_rolls(N,M,successful_rolls,current_roll):
        
    #fail condition if sum of dice less than actual number of dice - also works when total hits 0 and total negative
    if M<N: 
        return successful_rolls
    
    #even if we roll all sixes, can't reach sum - also works when total hits 0 and remaining sum too big
    if M>6*N: 
        return successful_rolls
    
    #following loop can only be reached if N=0 AND M=0, due to previous two conditions
    if N==0:
        return successful_rolls + [current_roll]
    
    for roll in range(1,7):
        successful_rolls = enumerate_rolls(N-1,M-roll, successful_rolls, current_roll + [roll])
    
    return successful_rolls #only gets reached when recursion branches exhausted

# %%
qq = enumerate_rolls(8,24,successful_rolls_init,current_roll_init)
# Out:
# time: 35.4 s

# %%
prods = np.prod(qq, axis=1)

# %%
prods.shape
# Out:
# (98813,)

# %%
np.mean(prods)
# Out:
# 1859.9329541659499

# %%
np.std(prods)
# Out:
# 855.06988534739196

# %%
qq = enumerate_rolls(7,21,successful_rolls_init,current_roll_init)
# Out:
# time: 1.08 s

# %%
print(len(qq))
print(qq)
# Out:
# 18327
# [[1, 1, 1, 1, 5, 6, 6], [1, 1, 1, 1, 6, 5, 6], [1, 1, 1, 1, 6, 6, 5], [1, 1, 1, 2, 4, 6, 6], [1, 1, 1, 2, 5, 5, 6], [1, 1, 1, 2, 5, 6, 5], [1, 1, 1, 2, 6, 4, 6], [1, 1, 1, 2, 6, 5, 5], [1, 1, 1, 2, 6, 6, 4], [1, 1, 1, 3, 3, 6, 6], [1, 1, 1, 3, 4, 5, 6], [1, 1, 1, 3, 4, 6, 5], [1, 1, 1, 3, 5, 4, 6], [1, 1, 1, 3, 5, 5, 5], [1, 1, 1, 3, 5, 6, 4], [1, 1, 1, 3, 6, 3, 6], [1, 1, 1, 3, 6, 4, 5], [1, 1, 1, 3, 6, 5, 4], [1, 1, 1, 3, 6, 6, 3], [1, 1, 1, 4, 2, 6, 6], [1, 1, 1, 4, 3, 5, 6], [1, 1, 1, 4, 3, 6, 5], [1, 1, 1, 4, 4, 4, 6], [1, 1, 1, 4, 4, 5, 5], [1, 1, 1, 4, 4, 6, 4], [1, 1, 1, 4, 5, 3, 6], [1, 1, 1, 4, 5, 4, 5], [1, 1, 1, 4, 5, 5, 4], [1, 1, 1, 4, 5, 6, 3], [1, 1, 1, 4, 6, 2, 6], [1, 1, 1, 4, 6, 3, 5], [1, 1, 1, 4, 6, 4, 4], [1, 1, 1, 4, 6, 5, 3], [1, 1, 1, 4, 6, 6, 2], [1, 1, 1, 5, 1, 6, 6], [1, 1, 1, 5, 2, 5, 6], [1, 1, 1, 5, 2, 6, 5], [1, 1, 1, 5, 3, 4, 6], [1, 1, 1, 5, 3, 5, 5], [1, 1, 1, 5, 
, 1, 2, 4, 5, 5, 3], [1, 1, 2, 4, 5, 6, 2], [1, 1, 2, 4, 6, 1, 6], [1, 1, 2, 4, 6, 2, 5], [1, 1, 2, 4, 6, 3, 4], [1, 1, 2, 4, 6, 4, 3], [1, 1, 2, 4, 6, 5, 2], [1, 1, 2, 4, 6, 6, 1], [1, 1, 2, 5, 1, 5, 6], [1, 1, 2, 5, 1, 6, 5], [1, 1, 2, 5, 2, 4, 6], [1, 1, 2, 5, 2, 5, 5], [1, 1, 2, 5, 2, 6, 4], [1, 1, 2, 5, 3, 3, 6], [1, 1, 2, 5, 3, 4, 5], [1, 1, 2, 5, 3, 5, 4], [1, 1, 2, 5, 3, 6, 3], [1, 1, 2, 5, 4, 2, 6], [1, 1, 2, 5, 4, 3, 5], [1, 1, 2, 5, 4, 4, 4], [1, 1, 2, 5, 4, 5, 3], [1, 1, 2, 5, 4, 6, 2], [1, 1, 2, 5, 5, 1, 6], [1, 1, 2, 5, 5, 2, 5], [1, 1, 2, 5, 5, 3, 4], [1, 1, 2, 5, 5, 4, 3], [1, 1, 2, 5, 5, 5, 2], [1, 1, 2, 5, 5, 6, 1], [1, 1, 2, 5, 6, 1, 5], [1, 1, 2, 5, 6, 2, 4], [1, 1, 2, 5, 6, 3, 3], [1, 1, 2, 5, 6, 4, 2], [1, 1, 2, 5, 6, 5, 1], [1, 1, 2, 6, 1, 4, 6], [1, 1, 2, 6, 1, 5, 5], [1, 1, 2, 6, 1, 6, 4], [1, 1, 2, 6, 2, 3, 6], [1, 1, 2, 6, 2, 4, 5], [1, 1, 2, 6, 2, 5, 4], [1, 1, 2, 6, 2, 6, 3], [1, 1, 2, 6, 3, 2, 6], [1, 1, 2, 6, 3, 3, 5], [1, 1, 2, 6, 3, 4, 4], [1, 1, 2, 6, 3, 5, 3], [1, 1, 2, 6, 3, 6, 2], [1, 1, 2, 6, 4, 1, 6], [1, 1, 2, 6, 4, 2, 5], [1, 1, 2, 6, 4, 3, 4], [1, 1, 2, 6, 4, 4, 3], [1, 1, 2, 6, 4, 5, 2 ...

# %%
qq + [[4,6,7,8]]
# Out:
# [[5, 3, 4], [4, 6, 7, 8]]

# %%
print(qq)
# Out:
# [5, 3, 4, [3, 9]]

# %%
r = r + [2]
print(r)
# Out:
# [5, 2, 2, 2, 2]

# %%
for roll in range(6):
    print(roll)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
18327*6
# Out:
# 109962

# %%
98813/18327
# Out:
# 5.391662574343864

# %%
98813 * 6**42
# Out:
# 47551760563203572200032955949402554368

# %%
def enumerate_rolls_alt(N,M,successful_rolls,current_roll):
    
    #following loop can only be reached if N=0 AND M=0, due to previous two conditions
    if N==0:
        if M==0:
            return successful_rolls + [current_roll]
        else:
            return successful_rolls
    
    for roll in range(1,7):
        successful_rolls = enumerate_rolls(N-1,M-roll, successful_rolls, current_roll + [roll])
    
    return successful_rolls #only gets reached when recursion branches exhausted
# Out:
# time: 5.93 ms

# %%
successful_rolls_init = [] 
current_roll_init = []
qq = enumerate_rolls_alt(8,24,successful_rolls_init, current_roll_init)
# Out:
# time: 36.2 s

# %%
len(qq)
# Out:
# 98813
# time: 1.92 ms

# %%
rnd.randint(1,7,[50,10000000])
# Out:
# array([[6, 5, 1, ..., 2, 3, 2],
#        [6, 4, 6, ..., 4, 2, 3],
#        [1, 5, 2, ..., 1, 6, 4],
#        ...,
#        [5, 6, 2, ..., 1, 3, 5],
#        [2, 3, 1, ..., 1, 4, 3],
#        [5, 3, 2, ..., 2, 5, 2]])
# time: 8.07 s
